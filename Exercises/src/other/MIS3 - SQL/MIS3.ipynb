# %% [markdown]
# ![alt text](image.png)

# %%
from sqlalchemy import create_engine

# Replace these values with your actual PostgreSQL credentials and database name
username = "probables"
password = "W$gU!OLWqvxQFwf3@TJYU*4sMFRQ27Gwm@igpKv#s$BGtc&dzBjj^R"  # Enter the correct password here
hostname = "localhost"
dbname = "aprenderon"

# Create the correct connection string
connection_string = f'postgresql://{username}:{password}@{hostname}/{dbname}'

# Create an engine
engine = create_engine(connection_string)

# Try connecting
with engine.connect() as connection:
    result = connection.execute("SELECT 'Hello, PostgreSQL!'")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\user\anaconda3\envs\py312\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\user\anaconda3\envs\py312\Lib\site-packages\sqlalchemy\engine\base.py:3302, in Engine.raw_connection(self)
#    3281 """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283 The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301 """
# -> 3302 return self.pool.connect()
#
# File c:\Users\user\anaconda3\envs\py312\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
# ...
