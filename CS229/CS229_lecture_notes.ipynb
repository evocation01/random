# %% [markdown]
# # 1.0 First Module
# - ML defs
#   - Arthur Samuel - 1959 (chess)
#     - field of study that gives computers the ability to
#       - learn w/o being explicitly programmed
#     - if n was lower (less games)
#       - then performance would be worse
#   - Tom Mitchell - 1998
#     - Well-posed Learning Problem
#       - a program will learn from
#         - experience E from task T with performance P
#           - if P improves with E.
#         - if P improves with E on task T

# %% [markdown]
# ## 1.1 Supervised Learning
# - learns from being given "right answers y"
# - used the most in real world apps
# - most rapid advancements
# - regression & classification alg's
# - x       ->  y
# - input   ->  output
#   - machine learns from right "y"s
# - <img src="image.png" alt="Sample Image" width="350">

# %% [markdown]
# ### 1.1.1 Regression Algorithms (∞)
# - predicts a number
# - infinitely many possible outputs
#   - outputs = ∞
# - <img src="image-1.png" alt="Sample Image" width="350">

# %% [markdown]
# ### 1.1.2 Classification Algorithms (n=2+)
# - predicts categories
# - small number of possible outputs
# - breast cancer detection
# - tumor (a lump)
#   - malignant
#   - benign
#   - various sizes & diagnosises
#     - data gives prediction
# - <img src="image-2.png" alt="Sample Image" width="350">
# - <img src="image-3.png" alt="Sample Image" width="350">
# - <img src="image-4.png" alt="Sample Image" width="350">

# %% [markdown]
# ## 1.2 Unsupervised Learning
# - find sth interesting
#   - in unlabeled data
# - inputs x given
# - outputs y not given
#   - goal: find structure
# - <img src="image-5.png" alt="Sample Image" width="350">
# - <img src="image-9.png" alt="Sample Image" width="350">
#   - answer: 2, 3

# %% [markdown]
# ### 1.2.1 Clustering
# - group similar data points
#   - together
# - <img src="image-6.png" alt="Sample Image" width="350">
# - <img src="image-7.png" alt="Sample Image" width="350">
# - <img src="image-8.png" alt="Sample Image" width="350">

# %% [markdown]
# ### 1.2.2 Anomaly detection
# - find unusual data points

# %% [markdown]
# ### 1.2.3 Dimensionality reduction
# - compress data using
#   - fewer numbers

# %% [markdown]
# ### 1.2.q Supervised vs Unsupervised learning
#
# 1) Which are the two common types of supervised learning? (Choose two)
# + Classification
# Clustering
# + Regression
#
# 2) Which of these is a type of unsupervised learning?
# Classification
# + Clustering
# Regression

# %% [markdown]
# ## 1.3 Recommender systems

# %% [markdown]
# ## 1.4 Reinforcement learning

# %% [markdown]
# ## 1.5 Regression Models
# - predicts numbers, ∈ (-∞,∞)
# - <img src="image-10.png" alt="Sample Image" width="350">
# - <img src="image-11.png" alt="Sample Image" width="350">

# %% [markdown]
# ### 1.5.0 Terminology
# - Training Set
#   - Data (dataset) used to train the model
# - x
#   - "input" variable
#   - "input" feature
#   - feature
# - y
#   - "output" variable
#   - "target" var
# - m
#   - number of training examples
# - (x,y)
#   - single training example
# - (x^(i), y^(i))
#   - i^th training example
#   - NOT exponent!
#     - x^(2) ≠ x^2
# - <img src="image-12.png" alt="Sample Image" width="350">
# - <img src="image-15.png" alt="Sample Image" width="500">

# %% [markdown]
# ### 1.5.1 Linear regression algorithm
# - Training set
#   - features
#   - targets
#   - learning algorithm (f)
#     - x -> f -> ŷ
#       - x : feature
#       - f : model
#       - ŷ : target = prediction (estimated y)
#         - f(x) = wx + b
#           - w: weight
#           - b: bias
# - <img src="image-13.png" alt="Sample Image" width="350"
# - <img src="image-14.png" alt="Sample Image" width="350"

# %% [markdown]
# #### 1.5.1.1 Optional Lab

# %%
# imports
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('bmh')
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# x_train is the input variable (size in 1000 square feet)
# y_train is the target (price in 1000s of dollars)
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
# m is the number of training examples
# Numpy arrays have .shape pmt.
print(f"x_train.shape: {x_train.shape}") # Returns a tuple with an entry for each dimension. 

m = x_train.shape[0] # using train.shape[0] numpy function
print(f"Number of training examples generated with numpy is: {m}")

m = len(x_train) # using length
print(f"Number of training examples generated with len() function is: {m}")
# Out:
# x_train.shape: (2,)
# Number of training examples generated with numpy is: 2
# Number of training examples generated with len() function is: 2

# %%
i = 0 # Change this to 1 to see (x^1, y^1)

x_i = x_train[i]
y_i = y_train[i]
print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)

# %%
plt.style.use('')
# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r')
# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.show()

# %%
w = 100
b = 100
print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 100
# b: 100

# %%
def compute_model_output(x, w, b):
    """
    Computes the prediction of a linear model
    Args:
      x (ndarray (m,)): Data, m examples 
      w,b (scalar)    : model parameters  
    Returns
      f_wb (ndarray (m,)): model prediction
    """
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
        
    return f_wb

# %%
tmp_f_wb = compute_model_output(x_train, w, b,)

# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b',label='Our Prediction')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')

# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %%
# w,b ranges of our model
# Let's predict the price of a house with 1200 sqft. Since the units of  𝑥are in 1000's of sqft,   x_i is 1.2.
w = 200
b = 100
x_i = 1.2
cost_1200sqft = w * x_i + b

print(f"${cost_1200sqft:.0f} thousand dollars")
# Out:
# $340 thousand dollars

# %% [markdown]
# #### 1.5.1.2 Cost Function
# - Squared error cost function
#   - 1/(2m) part makes it "average"
#     - (total cost function calculation is tough)
#   - we should try to make
#     - O.F. = min J(w, b)
#     - reason:
# - <img src="image-16.png" alt="Sample Image" width="350">
# - <img src="image-17.png" alt="Sample Image" width="350">
# - <img src="image-18.png" alt="Sample Image" width="350">
# -
# - Goal:
# -
# - <img src="image-19.png" alt="Sample Image" width="350">
# - <img src="image-20.png" alt="Sample Image" width="350">
# - <img src="image-21.png" alt="Sample Image" width="350">
# - <img src="image-22.png" alt="Sample Image" width="350">
# - <img src="image-23.png" alt="Sample Image" width="350">
# - <img src="image-24.png" alt="Sample Image" width="350">

# %% [markdown]
# ##### 1.5.1.2.1 Visualization of Cost Function
# - With only pmt w
#   - J(w) was a curve
# - with parameters w & b
#   - a more complex plot (3D)
#   - use contour plot instead!
#     - the center of the plot
#       - is the min J(w,x)!
# - <img src="image-25.png" alt="Sample Image" width="350">
# - <img src="image-26.png" alt="Sample Image" width="350">
# - <img src="image-27.png" alt="Sample Image" width="350">
# - <img src="image-28.png" alt="Sample Image" width="350">

# %% [markdown]
# ###### 1.5.1.2.1.1 Examples of Visualization
# - <img src="image-29.png" alt="Sample Image" width="350">
# - <img src="image-30.png" alt="Sample Image" width="350">
# - <img src="image-31.png" alt="Sample Image" width="350">
# - Best fit (center)
# - <img src="image-32.png" alt="Sample Image" width="350">
