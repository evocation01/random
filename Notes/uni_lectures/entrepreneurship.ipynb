# %% [markdown]
# # cSpell:disable
# - toplum için değer yaratmak
# - para öncesinde,
#   - inanç, azim, cesaret
# - amaçlar
#   - kar
#   - sürdürülebilirlik
#   - kar elde etmek
#   - satisfaction and acquiring demand
# - paydaşlar
#   - müşteri
#     - yüksek parasal değer
#   - hissedar
#     - yüksek kar
#   - çalışan
#     - iyi maaş
#     - çalışma koşulları
#   - tedarikçi
#     - kárlı ilişkiler
#   - dağıtıcı
#     - kárlı ilişkiler
#   - gov
#     - vergi&kural uyum
#   - nature
#     - gelecek nesillere aktarım
# - DEĞER
#   - en önemli sorumluluk
#     - yenilik

# %% [markdown]
# # cSpell:disable
#
# - Richard Cantillon
#   - girişimci, henüz belirginleşmemiş bir fiyatla satmak üzere üretimin girdilerini satın alan veya üreten kişidir.
#     - risk ve belirsizlik
# - Jean Baptiste Say
#   - ticari ürünler üretmek amacıyla çalışan
#     - doğal kaynaklar ve sermayeden oluşan üretim faktörlerini bir araya getirme sorumluluğu olan kişi
#       - yönetim
# - Joseph Schumpeter
#   - yenilik yaparak toplum refahını arttırmak temel sorumluluktur
#
# - belirli bir getiri sağlamak için risk alan ve üretim faktörlerini bir araya getirerek yenilik yapma sorumluluğu olan kişi
# - DEĞER OLUŞTURMAK

# %% [markdown]
# # cSpell:disable
# - işletme
#   - amaç
#   - istek
#   - ihtiyaç
#   - ürün
# - amaçlar
#   - ticari
#   - iktisadi
#     - (non-profit)
# - işletme ve girişim
#   - Ziraat bankası bir girişim
#     - şubeleri bir işletme
#       - girişim, işletme'yi içine alan daha geniş bir kavram
# - Yönetim
#   - verilen kararlar
#   - Planlama
#     - ne? ne zaman? kim? hangi amaçla?
#   - Örgütleme
#     - nasıl bir yapı?
#   - Koordine Etme (Yürütme) (Yöneltme)
#     - çalışanlar arası amaç birliği oluşturmak
#   - Kontrol
#     - eval ? achieved purposes : ask why

# %% [markdown]
# # cSpell:disable
# - KOBİ
#   - mikro, küçük veya orta ölçekli işletme
#   - it varies with country to country
#   - in tr
#     - mikro
#       - <10
#       - <3 milyon TL
#     - küçük
#       - <50
#       - <25 milyon TL
#     - orta
#       - <250 yıllık çalışan
#       - <125 milyon TL yıllık net satış hasılatı veya mali bilanço
#   - işletmelerin tr'de %99,8'i
#   - sistemleri daha esnek
#   - düşük pazarlarda faaliyet +
#   - daha verimli yenilikler
#   - motivasyon +
#   - küçük birikim
#   - girişimcilik
#   - büyük işletmelerin tamamlayıcıları
#   - tecrübeli personal eksikliği
#   - maliyet yüksek
#   - fiyat rekabeti -

# %% [markdown]
# # cSpell:disable
# - nitelikler
#   - öz yeterlilik
#     - against problems, don't falling, trusting oneself
#     - yenilik
#     - risk alma
#     - finansal kontrol
#     - pazarlama
#     - yönetim
#   - yenilikçilik
#     - yeni pazarlar
#     - yeni dağıtım kanalları
#     - farklılaştırma
#       - ürün geliştirme how?
#       - farklı ürün yaratabilir miyim?
#   - risk alma
#     - riski min. etme
#     - kazançlara göre riski ayarlama
#   - liderlik
#     - yönlendirmek
#     - motive etmek
#     - dürüst
#     - güvenilir
#     - azimli
#     - kararlı
#     - kendine güvenen
#     - vizyon sahibi
#     - iletişim yeteneği yüksek
#     - güven duygusu yaratmak

# %% [markdown]
# # cSpell:disable
# - Girişimcilik motivasyonları
#   - güvenliğe yönelik
#     - geleceği güvenceye almak
#   - maddi/dışsal
#     - refah
#     - para
#   - bireysel/içsel
#     - duygusal
#     - içsel
#     - fighting difficulties
#   - bağımsızlığa yönelik
#     - kendi kararlarını vermek
#     - kişisel özgürlük
# - Girişimcilik Engelleri
#   - uzun ve belirsiz saatler
#   - düzensiz gelir
#   - stres
# - Başarısızlık Faktörleri
#   - her yıl işletmelerin %70'i kapanıyor
#   - gider > gelir
#   - araştırma
#     - müşteri doğrulaması
#     - potential customers
#     - ilişkiler
#   - ölçüsüz büyüme
#     - planlama
#     - ölçümleme
#   - Nakit yetersizliği
#     - ölüm vadisi
#       - geliştirmeden sonra geçen süre
#         - harcama = gelir
#   - ekip ile ilgili
#     - teknik bilgiler
#   - çevresel nedenler
#     - econ, social, cultural, legal
# - ![alt text](image-5.png)

# %% [markdown]
# # cSpell:disable
# - girişimcilik süreci
#   - değer yaratma
#   - fırsat tespit
#     - fırsat & sorun -> değer
#     - değişimler euroka!
#     - makro çevre faktörleri
#     - micro fırsatların incelenmesi
#       - econ
#       - tech
#         - üretim süreci
#         - rekabet
#       - demografik
#         - artan nüfus
#           - yaşlı bakım
#       - yasal
#   - iş modeli & planı
#     - somut adımlar için
#     - plan > model (kapsam)
#   - kaynaklar
#     - insan
#       - ekibe bağlı
#     - sermaye
#       - öz sermaye
#       - arkadaş&aile
#       - melek
#       - banka kredi
#       - kamu fon
#   - büyüme & çıkış
#     - kaynakların verimli kullanılması
#     - when?
#     - yatırım
# - girişimcilik efsaneleri
#   - E1
#     - iş fikri en önemli konudur
#   - E2
#     - iş fikri karmaşıksa başarı garantidir
#   - E3
#     - ürün kimsede yoksa başarı garantidir
#   - E4
#     - öz kaynakla kurulacaksa iş planı hazırlamak gereksiz.
#       - amaç riski azaltmak!
#   - E5
#     - iş fikrini kimseyle paylaşma.
#       - brainstorming!
#   - E6
#     - başarısız girişimciye güvenilmez.
#       - başarısızlık ~ yenilikçililk
#   - E7
#     - girişimciler risk almayı sever
#       - amaç riski azaltmak!
#       - karar vericilik!
#   - E8
#     - girişimcilik parası olanların işidir

# %% [markdown]
# # cSpell:disable
# - Fikir
#   - tohum -> ürün
#   - para?
#   - kime satılacak?
#   - kár?
# - başarı
#   - orijinal fikir X
#   - sır gibi saklanmalı X
#   - doğru zaman +
#   - doğru yer +
#   - doğru şekilde +
#     - plan
#     - analiz
# - Fırsat
#   - çevre ve içsel
#   - tech
#   - pazar trendleri
#   - yasalar
# - Problem
#   - müşterilerin sorunu

# %% [markdown]
# # cSpell:disable
# - Girişimler
#   - Mailchimp
#     - e-posta tasarımı
#   - Shopify
#     - Tobias Lütke
#     - Scott Lake
#   - WeWork
#     - Adam Neumann
#     - Miguel McKelvey
#     - binaların boş alanlarını ayarlama
#   - Dropbox
#     - Drew Houston
#   - Malwarebytes
#     - Marcin Kleczynski
#     - when he's 14 lol
#   - Facebook
#     - M.Z.
#     - coursematch
#     - facemash
#   - Google
#     - Larry Page
#     - Sergey Brin
#     - PageRank algoritması
#   - Joy Mangano
#     - paspas
# - problemi fark etmek
#   - etkili çözüm
#     - girişim ve başarı
# - ihtiyaç
#   - kişinin eksikliğini hissettiği şey
#     - ihtiyaç mp3 değil, şarkı dinlemektir
#     - ihtiyaç araba değil, hızlı gitmektir
#       - örneğin eski dönemde hızlı bir at olurdu cevap

# %% [markdown]
# # cSpell:disable
# - müşteri keşfi
#   - görüşmeler
#     - karşı tarafı konuşturun
#     - doğrudan satış yapıcı şeyler söyleme!
#       - xxx, alır mıydınız?
#   - yaptıkları ile ilgilen
#   - Tasarımsal düşünme yöntemi
#     - müşteri anlama
#     - problemlere odaklan
#     - fikir geliştir
#     - model
#   - Yapılacak işler yöntemi
#     - motivasyon
#     - araçlar
# - inovasyon
#   - yenilik
#     - pazarda fark
#     - rekabette avantaj
#   - iş modeli
#   - müşteri deneyimi
#   - iş ağı
#   - satış kanalı
#   - ürün perf
#   - ürün sunum
#   - işe yarar yenilik
#     - müşteri
#       - dinle
#       - ihtiyaç & sorun
#       - ortak sorunların pazar büyüklüğü
#     - tech
#       - nanotech
#     - pazar
# - trendleri takip etme yöntemleri
#   - pazarı takip etme yöntemi
#     - paylaşım ekonomisi
#       - airbnb vb.
#   - jenerasyonları takip etme yöntemi
#     - sosyal bankacılık
#   - regülasyonları takip etme
#     - ödeme kuruluşları lisansı
#   - tech gelişmeleri takip etme
#     - üç boyutlu yazıcı
#     - yapay zeka
#     - nanotech
#     - VR/AR

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable
# - değer önerileri
#   - hangi değer
#   - hangi problem/ihtiyaç karşılanıyor
#   - kim? özellik?
#   - duvara eşya sabitleyebilmek
#     - bant
#   - performans
#   - yenilik
#   - kişileştirme
#   - marka
#   - tasarım
#   - fiyat
#   - maliyet kontrolü
#   - erişim
#   - kolay kullanım
#     - her bir müşteri için farklı değer önerisi bul.
# - gelir kaynakları
#   - satış
#     - fiyat <-> maliyet (f/p)
#   - kiralama
#   - kullandıkça öde
#     - kullanıma bağlı
#   - abonelik
#   - gelir modeli
#     - nasıl para kazanılır
#     - bedelsiz ve primli
#       - çok depolama : paralı vb.
#     - SaaS (hizmet olarak yazılım)
#       - bulut tabanlı
#       - kullandıkça öde
#     - doğrudan satış
#       - satış elemanı istihdamı
#     - reklam destekli
#       - Kullanıcılardan ücret almak yerine onlara ürünlerini tanıtmak isteyen başkalarından gelir elde etmek.
#     - pazar yeri
#       - yemeksepeti
#       - komisyon vb.
#       - armut.com
#       - sahibinden.com
#       - alibaba
#     - yem ve olta
#       - ucuza satılan bir ürünle oltaya alınır
#         - gilette
#           - yeni bıçaklar pahalı vb.
#         -

# %% [markdown]
# # cSpell:disable
# - girişim başarısı
#   - yakın çevre koşulları
#   - uzak çevre koşul
#   - ekonomik
#     - talep
#     - maliyet
#     - kaynak erişim kısıtlamaları
#     - doğru analiz
#     - etkileri belirlemek
#     - önlem almak
#     - econ gösterge
#       - büyüme hızı
#         - econ büyüme
#           - üretim faktörleri
#             - miktar artışı
#             - verimlilik iyileşmesi
#       - faiz
#         - fonların maliyeti
#       - döviz
#         - talep
#       - işsizlik
#         - iş gücü arzı
#         - iş gücü istihdamı
#         - araştırma & inceleme
#       - enflasyon

# %% [markdown]
# # cSpell:disable
# - endüstri
#   - benzer üretim süreçleri ve ürünler
#   - işletmeler
# - pazar
#   - benzer ihtiyaç ve talep
#   - müşteriler
# - rekabet faktörlerini tanımla
# - Michael Porter
# - Endüstrinin Beş Faktör Analizi
#   - Müşteri
#   - rakip
#   - tedarikçi
#     - işletmenin beklentilerini karşılamalı
#     - makul fiyat
#     - zamanında
#   - üretici
#   - yeni firmalar
# - pazarlık gücü yüksek müşteriler
#   - işletmeler ideal olmayan fiyata verebilir
# - rekabet şiddeti
#   - haksız rekabet
#     - yıkıcı
#     - girişim rekabet avantajı elde edecek mi
#       - daha yüksek bir değer
#       - op etkinliği
#         - ucuz hızlı üretim
#   - akılcı prensipler
#   - deals & promotions
#   - tehditler
#     - yeni girişimler
# - ikame ürün üreticilerinin oluşturabileceği tehditler
#   - otobüs vs uçak
# - diğer
#   - zamanla sektörün türü & durumu
#     - mevzuatlar
#     - kısıtlamalar
#     - talep değişimi
#     - fiyata tepki
# - veri kaynakları
#   - genelde hazır bulunmaz
#   - mülakat

# %% [markdown]
# # cSpell:disable
# - talebi ve müşteriyi anlamak
#   - müşteri
#     - nihai karar verici
#     - ?????
#       - kim satın alıyor? kim kullanıyor
#         - memnuniyet
#         - marka
#       - seçim kriterleri
#         - fiyat
#         - marka
#         - perf
#         - şekil
#         - satın alma yöntemi
#       - Ne zaman alıyor? Ne zaman kullanıyor?
#       - nereden? nasıl satın alıyor?
#         - internet, tel, elden vb.
#       - neden? nasıl kullanıyor?
#         - dayanıklılık
# - talep tahmini
#   - max coğrafi pazar
#   - müşteri sayısı
#   - müşterilerin ortalama tüketimi
#     - veri analizi
#     - geçmiş talep verileri
#       - forecasting ve trend analizleri
#     - benzer ürünlerin geçmiş talep verileri
#     - veri yoksa
#       - pzar araştırması şirketleri
#       - pot. müşteri görüşmeleri
#       - uzmanlardan öneri
#     - Delphi yöntemi
#       - 1 geniş kitleye talep tahminleri sorulur
#       - 2 sonuçları sorulur, görüşleri sorulur
#       - görüş birliğine kadar 1-2'ye devam
#     - Pazar testi
#       - deneme amaçlı ürün
#       - aktörlerin tepkisi
#     - birçok yöntem kullanılmalı
#       - amaç en güvenli talep tahmini yapmak

# %% [markdown]
# # cSpell:disable
# - hukukta girişimci
# - TCK 6102. Maddesi:
#   - Ticari işletme:
#     - Esnaf işletmesi için öngörülen sınırı aşan düzeyde gelir sağlamayı hedef tutan faaliyetlerin devamlı ve bağımsız şekilde yürütüldüğü işletmedir.
# - kendi adına işletir
#   - esnaf, tacir, sanatkar, tüccar, müteşebbis
#     - esnaf
#       - sermayesini bedení çalışma
#       - kazanç miktarı tacir/sanayici altında
#       - gelir vergisinden muaf olabilir
#       - defter tutmayabilir
#     - tacir
#       - gelir vergisi +
#       - defter +
#       - gerçek/tüzel
#       - ticaret sicili
# - ortak & şirket aracığıyla işletir
#   - ortak, hissedar
# - sermaye (TTK M.127)
#   - para
#   - alacak
#   - kıymetli evrak
#   - paylar
#   - fikri mükriyet hakları
#   - taşınırlar ve taşınmazlar
#     - ve faydalanma hakları
#   - kişisel emek
#   - ticari itibar
#   - ticari işletmeler
#   - devredilebilir alanlar, e-ortamlar, adlar, işaretler
#   - ekonomik ruhsatnameler
#   - devrolunabilen / nakden değerlendirilebilen her türlü değer
# - işletme türleri
#   - kollektif
#   - komandit
#   - anonim
#   - limited
#   - kooperatif
#   - şahıs şirketleri
#     - kollektif ve komandit
#     - şahsiyet önemli
#     - alacaklı kar payından / tazviye payından alır
#   - sermaye şirketleri
#     - anonim
#     - limited
#     - sermayesi paylara bölünmüş komandit
#     - sermaye önemli
#       - kar payı / tazviye payı / payları haczedilebilir
#
# ![alt text](image-6.png)

# %% [markdown]
# # cSpell:disable
# - ticaret şirketlerinin & kooperatiflerin kurulma aşamaları
#   - sözleşme
#   - noter
#   - tescil
#   - TTS gazetesinde sicil ilanı
#   - esnaf/sanatkar/ticaret/sanayi/deniz ticaret odasına tescil
#   - defterleri tesdik
#   - gib
#   - sgkya tescil
# - limited şirketler
#   - TTK m.573 : Limited şirket, kanunen yasak olmayan her türlü econ amaç & konu için kurulabilir.
#     - 1+= gerçek/tüzel kişi
#       - tüzelse mal varlığı ve borçları ayrı
#     - ticaret unvanı altında
#     - sermaye belirli
#     - esas sermaye payların toplamından
#     - ortaklar şirket borçlarından sorumlu değil
#   - iş devam ederken hukuki durumlar
#     - yönetim temsil
#       - ana sözleşme
#         - teşebbüs unvanı
#         - merkez/şube
#         - ortaklar/faaliyetler
#       - yetkisi herkese verilebilir.
#     - müdürlerin yetkileri
#       - zararlardan sorumlu
#     - başlangıç sermayesi
#       - ortak payları
#       - vadeli alım
#       - kredi
#       - borç
#     - haklar ve sorumluluklar
#       - temel hakkı, amaçları doğrultusunda faaliyet
#       - müdür
#         - huzur hakkı isteme
#         - yönetme
#         - temsil etme
#       - ortaklar
#         - kardan pay almak
#         - pay devri
#         - genel kurul & oy
#         - bilgi almak
#         - denetlemek
#         - ortaklıktan çıkmak
#         - sermaye koymak
#         - ek ödeme yapmak
#         - şirket sırlarını korumak
#     - çek
#       - kıymetli evrak
#       - "çek" metin üstünde olmalı
#       - bankaya ibraz edilir süresi içinde
#       - keşide edildiği (düzenlendiği) yerde ödenecekse 10 gün içinde muhataba ibraz edilmeli
#       - Düzenleyenin ölümü, medenî haklarını kullanma ehliyetini kaybetmesi veya iflası çekin geçerliliğini etkilemez
#     - bono
#       - kredi vasıtası
#       - vade tarihinde şartsız öder
#     - sözleşme yapmak
#       - genelde yazılı
#       - min 2 kişi
#         - gerçek veya tüzel
#       - sözleşmeye uyum olmazsa
#         - ihtar & ihbar
#           - noter
#           - taahütlü mektup
#           - telgraf
#           - güvenli e-imza
#     - 6502 tüketicin korunması hakkında kanun
#       - ayıplı mal
#         - örneğe uygun olmayan
#         - özellikleri taşımayan
#         - sözleşmeden dönme
#         - indirim isteme
#         - ücretsiz onarılma
#         - değişim
#     - serbest rekabet
#       - devlet
#         - kanunlarla korumayı amaçlar
#           - m.4054 Rekabetin Korunması Hakkında Kanun
#             - rekabeti bozucu anlaşmalar -
#             - uyumlu eylemlerini
#             - işletme birliği kararlarını
#             - hakim durumunun kötüye kullanılmasını yasaklar
#       - başkasına ait markayı kullanmak
#       - kayıt dışı işçi
#       - başka ürüne dayalı yanılgı oluşturmak
#     - Marka ve Tescili Kullanımı
#       - 6769 sayılı Sınai Mülkiyet Kanunu m.4(1)
#         - marka, ayırt edilebilmeyi ve kesin anlaşılmayı sağlayabilecek şekilde
#           - sicilde gösterilebilir her türlü işaretten oluşabilir
#       - 6769 sayılı Kanun madde 9
#         - ciddi biçimde kullanılmayan veya 5 yıl kesintisiz kullanılmayan markanın iptaline karar verilir
#     - İSG - iş sağlığı ve güvenliği
#       - şirketlerde önlemleri almak yükümlülüğü
#       - işçilerin önlemlere uyma
#     - Ortaklıktan Çıkma & Çıkarılma
#       - sözleşmeye göre
#         - haklı sebeple dava açılabilir
#           - 3 ay içinde
#
# - iş sona ererken hukuki
#   - tacirin ölmesi
# - Limited şirketler için
#     - sözleşmede öngörülen sona erme sebeplerinden biri
#     - genel kurul kararı
#     - iflas
#     - ve Kanunda öngörülen diğer (TTK m.636(1))
#       - tasfiye
#         - sicil silinir

# %% [markdown]
# # cSpell:disable
# - pazarlama
#   - ürün tanıtımı
#   - satış
#   - ürün geliştirme
#   - tutundurma
#   - dağıtım
#   - fiyatlama
#     - ihtiyaç
#       - tatmin edilmemiş dürtü
#       - Maslow
#         - kendini gerçekleştirme
#         - prestij, başarı, saygı
#         - ait olma ve sevilme
#         - güvenlik
#         - nefes, yeme, içme, barınma
#       - görünen
#         - ucuz bir araba
#       - gizli
#         - "akıllı bir tüketici" olarak algılanmak istemek
#       - gerçek
#         - bakım gideri az olan bir araba
#       - haz veren
#         - ücretsiz nav sistemi
#       - görünmeyen
#         - iyi bir hizmet
#     - istek
#       - kültür + kişilik + çevre
#         - su bir ihtiyaç
#           - gazoz, kola bir istek
#       - ihtiyaçları karşılayan objelerdir
# - tüketici
#   - kullanan veya tüketen
#   - birey, işletme
#   - cep telefonu kullanan birisi
# - müşteri
#   - satın alma kararı veren kişi
#   - apple markasının müşterisi
# - talep
#   - satın alma gücü ile desteklediği istek
# - ürün
#   - ticari x
#   - hizmet
#   - deneyim
#   - kişi
#   - mekan
#   - org
#   - fikir
# - değer
#   - üründen elde edilen
#     - fayda
#   - müşteri değer üçlüsü
#     - kalite
#     - hizmet
#     - fiyat
# - müşteri tatmini
#   - ürünün müşteri beklentisini karşılama derecesi
# - pazarlama
#   - odak noktası
#     - istek & ihtiyaç dikkate alınarak
#     - değer önerisi
#     - müşteriyi tatmin etme
# - pazarlama yönetim süreci
#   - analiz
#     - SWOT analysis (GZFT...)
#   - planlama
#     - stratejik planlama
#     - pazarlama planlaması
#       - fırsatlar analizi
#       - hedef
#       - strateji
#       - pazarlama karması
#   - uygulama
#     - planlara uygun olarak faaliyetlerin yürütülmesi
#     - nitelikli ekip
#   - kontrol
#     - sonuçların ölçülmesi
#       - değerlendirilmesi
#     - gerekli önlemler
#     - karşılaştırma
#       - önlem
#         - feedback

# %% [markdown]
# # cSpell:disable
# - pazar fırsatları
#   - yeni istek ve ihtiyaçları
#     - bunu giderecek ürün ve hizmetleri
#       - yeni yöntemler & pazarlama araçları
#   - sürekli analiz
#     - durum analizi
#       - SWOT
#         - OT (fırsat ve tehditler)
#           - PEST analizi (çevre analizi)
#             - politik
#               - devlet
#             - econ
#               - döviz
#               - kredi
#               - enflasyon
#               - macroecon
#               - hammadde
#               - işçilik
#               - sektör büyüme
#               - dış ticaret
#             - sos
#               - nüfus
#             - tech
#   - kısa dönemde kárlı (yağmurda şemşiye satmak gibi)
#   - ürünü iyileştirmek
#   - yepyeni bir ürün
#     - ar&ge
# - talep tahminleme
#   - belirli bir zaman
#     - ne kadar satış
#   - pazar testleri
#     - pazar potential
#       - deneyimler alınır
#   - yargısal tahmin
#     - uzmanların fikri
#   - tüketici anketleri
#   - veriye dayalı
#     - birden çok method
# - pazar bölümleme
#   - coğrafik
#     - iklim vb.
#   - demografik
#     - nüfusa göre
#     - cinsiyet gibi
#   - psikografik
#     - sosyal sınıf
#     - yaşam tarzı
#     - kişilik
#   - alıcı davranışına göre
#     - fayda
#     - kullanım derecesi
#     - markaya bağımlılık
#   - ölçülebilirlik
#   - ulaşılabilirlik
#   - büyüklük
#   - farklılaştırılabilirlik

# %% [markdown]
# # cSpell:disable
# - hedef pazar seçimi
#   - firmanın hizmet etmeyi planladığı tüketiciler
#     - ortak bir ihtiyacı var
#   - girişimci
#     - farklılaştırılmamış pazarlama (en geniş hedefleme)
#       - hiçbir farklılaştırma yok
#     - farklılaştırılmış
#       - bölümlerin beklentilerine uygun pazarlama karma
#       - en çok kullanılan
#     - yoğunlaştırılmış
#       - tek pazar
#     - mikro (en dar hedefleme)
#       - belirli bir kişi/bölgeye göre
# - pazar konumlaması
#   - hedef kitleye markayı anlatır
#   - rakiplerin konumlarını incele
#     - işletme için en uygunu belirle
#       - daha iyi bir değer
# - doğrudan
#   - cola v pepsi
# - dolaylı
#   - cola v dimes
# - pazarlama karması
#   - tüketici tepkisini belirlemek için kullanılan değişkenler
#     - ürün
#       - öz ürün (iphone)
#         - hangi sorunu çözer?
#         - hangi değer?
#           - eğlence
#           - prestij
#           - yaşam tarzı
#       - somut ürün
#         - marka
#         - ambalaj
#         - kalite
#         - tasarım
#       - genişletilmiş ürün
#         - montaj
#         - garanti
#         - teslim
#         - kredi
#         - servis
#       - ürün özellikleri
#         - kalite
#         - markalama
#         - ambalajlama
#       - ![image.png](attachment:image.png)
#     - fiyat
#       - rekabet
#       - değer algısı (f/p)
#         - değer yönlü fiyatlama
#           - ref. tüketicinin değer algısı (vb. iphone)
#         - maliyet yönlü fiyatlama
#           - maliyete göre
#           - rekabet
#           - sabit ve variable maliyetler
#           - (birim maliyeti) / 1 - (kar marjı) -> satış fiyatı
#     - dağıtım
#       - dağıtım kanalı tasarımı
#         - kaç katman
#         - kaç farklı kanal
#         - sıfır katmanlı
#           - web-sitesi
#         - bir katmanlı
#           - genelde perakendeciler
#         - iki katmanlı
#         - yoğun dağıtım
#           - çok sayıda yerde
#         - sınırlı dağıtım
#         - özel dağıtım
#           - tek bir aracı
#     - tutundurma
#       - ürünün hedef kitle tarafından kabul edilmesine yönelik
#         - ikna edici iletişim
#       - reklam
#         - bilgi verme
#         - hatırlatma
#         - ikna etme
#       - satış geliştirme (promosyon)
#         - kısa sürede ürünün satışlarını arttırmayı hedefleyen faaliyetler
#         - promosyonlar
#         - tüketici
#           - ürün dağıtımı
#           - kupon
#           - yarışma
#           - çekiliş
#         - aracı
#           - toptancı
#           - bayi
#           - perakendeci
#       - kişisel satış
#         - satış elemanı
#           - sipariş alma
#           - teslim etme
#           - destek
#       - halkla ilişkiler
#         - olumlu bir imaj amaçlı
#         - itibar
# - pazarlama faaliyetlerin yönetimi
#   - organizasyon
#   - kaynakları bul
#   - işletme amacı
#   1. aşama
#     - org. belirlenmesi
#   2. aşama
#     - ekibin oluşturulması
#   3. aşama
#     - operasyon'un başlatılması
#   - kontrol preosedürleri
#   - hedeflerin kontrolü
#   - kontrol çizelgeleri
#   -

# %% [markdown]
# # cSpell:disable
# # İleri Seviye Girişimcilik Programı
# - networking'in önemi
#   - tanışma
#   - tanıştırma
#   - tanınma sanatı
#   - çevre oluşturma
#   - başarıyı %70 arttırıyor
#   - hedef ve vizyon
#   - bilgi paylaşmak
#   - örümcek ağı
#     - sembol
#   - talepte bulunmak
#     - hatırlama
#     - hatırlanma
#     - ilişkileri güncel tutmak
#       - sohbet
#   - etkinliklere katılmak
#   - sohbet etmek
# - network ne değildir
#   - kartvizit değildir
# - tanınmak
# - zaman kazanmak
# - kaliteli hayat
#   - fırsatlardan haberdar olma
# - aktif tanınma
#   - doğrudan etkili
# - dolaylı tanınma
#   - zaman içerisinde
#   - iyi ilişkiler sonucunda

# %% [markdown]
# # cSpell:disable
# - networking
#   - hedefler
#     - zaman
#     - satış miktarı
#     - kazanç
#     - çevre faktörü
#   - iş kurma süreci networking planı
#   - en iyi kim bilir
#   - mevcut çevrenin incelenmesi
#   - tanışmaya hazırlık
#     - araştırma
#     - hazırlık listesi
#   - tanışma sırasında
#     - başlarken
#     - ilerlerken
#     - ayrılırken
#   - Takip stratejilerinin belirlenmesi
#   - Tanıştırmanın önemi ve püf noktaları
#   - Tanınma ve kişisel imajın oluşturulması
#   - Kitle önünde sunum
#     - hayal
#     - iş fikri & modeli
#     - sunum
#   - networking'de sosyal ağların kullanımı

# %% [markdown]
# # cSpell:disable
# - networking halkaları
#   - ortaklar & ekip & yönetim
#   - hedef kitle & aile & arkadaşlar & tedarikçiler
#   - mentor & finansal kuruluşlar & yatırımcılar & STK (sivil toplum kuruluşları), özel kuruluşlar, rakipler vb.
# - aktif tanınma
#   - doğrudan etkisi olduğu tanınma süreci
# - ağızdan ağıza
#   - Girişimcinin ziyaret edilecek kişi ya da etkinlik hakkında fikri olduğuna inandığı çevresini aradığı ve onların geribildirimlerini değerlendirdiği networking için arama yöntemi aşağıdakilerden hangisidir?

# %% [markdown]
# # cSpell:disable
# - muhasebe
#   - para birimi
#   - finansal tablo
#     - kullanıcılara sunulur
#     - bilanço
#       - finansal durum tablosudur
#       - durağan
#       - aktif
#         - dönen ve duran
#       - pasif
#         - kısa&uzun vadeli yabancı
#         - özkaynaklar
#       - Aktif = pasif
#       - varlık = kaynak
#     - gelir tablosu
#       - finansal perf tablosu
#       - net kár ve zarar
#     - nakit alış tablosu
#       - nakitteki değişim
#     - özkaynak değişim tablosu
#     - dipnotlar
#       - tamamlayıcı açıklamalar (tablolarda)
# - finansal yöntem politikaları
#   - (örnekler bilanço için)
#   - fon bulma
#     - ex: yabancı kaynaklar
#   - fonları kullanma
#     - ex: dönen & duran
#   - kár dağıtım
#     - ex: özkaynak grubu
# - finansal kaynaklar
#   - kaynak
#     - yabancı
#     - özkaynak
#   - vade
#     - kısa vadeli kaynaklar
#     - orta
#     - uzun
# - otofinansman
#   - işletmenin fon elde etmesi
#   - kullanım alanları
#     - sabit sermaye
#       - bilanço duran varlıkları
#       - arazi, bina, tesis, makina, cihaz, kuruluş, örgütlenme
#     - işletme sermayesi
#       - bir yıl içinde nakde dönüştürülebilecek varlıkların tümü
# - işletme sermayesi ihtiyacını tespit etme yöntemleri
#   - faaliyet devri katsayısı
#     - MSA
#       - faaliyet devri süresi = 70 gün, gider 1000 TL
#       - faaliyet devri katsayısı = 365/70=5,214
#       - işletme sermayesi = 1000 * 5,214 = 5214
#     - satışların yüzdesi yöntemi
# - nakit yönetimi
#   - en uygun nakit tutarını belirlemek
#   - İFMVQ
#     - ![alt text](image-7.png)

# %% [markdown]
# # cSpell:disable
# - stok çeşitleri
#   - hammadde
#   - ticari mal
#   - yarı mamul
#   - mamul
# - stok maaliyetleri
#   - tedarik
#   - alış
#   - stok bulundurma
#   - stok yönetim sistemi
# - ![alt text](image-8.png)

# %% [markdown]
# # cSpell:disable
# - işletme sermayesi
#   - İşletmelerin günlük işletme faaliyetlerini yürütebilmeleri için gerekli olan nakit ve nakit benzeri varlıklar ile bir yıl içerisinde nakde dönüştürülebilecek varlıkların tümünü ifade eden
# - nakit oran
#   - İşletmenin bir an için alacaklarını tahsil edilememesi durumunda kısa vadeli borçlarını ödeme gücü hakkında bilgi veren oran
# -

# %% [markdown]
# # cSpell:disable
# - vade faktoringi
#   - Faktoring şirketinin sadece tahsilat hizmeti sunduğu faktoring türü aşağıdakilerden hangisidir?
# - Mal veya hizmetin vadeli olarak alımı ya da satımı gibi ticari işlemler yapılırken aynı anda otomatik olarak finansmanın da sağlandığı borç bulmaya yönelik finansman türü aşağıdakilerden hangisidir?
#   - spontan finansman
# - Girişimcinin yararlanabileceği temel finansal kaynaklardan biri olan girişim sermayesi uygulamasıyla ilgili aşağıdakilerden hangisi doğrudur?
#   - kar elde etmeye başlamış girişimler için
# - “Melek yatırımcılar; yatırım açısından daha riskli olan erken evredeki girişimlere genellikle küçük miktarlarda finansman ve bu finansmanla birlikte satış, pazarlama, insan kaynağı tedariki ve eğitimi, yönetim gibi hususlarda da destek olan varlıklı şahıslardır.”
#   - Yönetici pozisyonunda herkes melek yatırımcı olabilir (yanlış)
# -

# %% [markdown]
# # cSpell:disable
# - Section: What is the query about?
#   - This section should contain a brief description of the user's query.
# Describe each non-obvious object in the query.
# Expand all abbreviations and number sequences in the query.
# For queries involving individuals, describe their field of activity or why they are notable.
# Add a translation of the query if it is in a foreign language.
# Describe the user's primary intents.
# If the query is incomplete or unclear, try to accurately describe what the user intended.
# Avoid excerpts from Wikipedia. Convey the meaning of the query without overly detailed definitions.
# If you can't grasp the overall meaning of the query, try to characterize its parts.

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable

# %% [markdown]
# # cSpell:disable
