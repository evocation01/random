# %% [markdown]
# # IBM SQL
# ## Week 1
# FilmLocations(
# Title:              titles of the films,
# ReleaseYear:        time of public release of the films,
# Locations:          locations of San Francisco where the films were shot,
# FunFacts:           funny facts about the filming locations,
# ProductionCompany:  companies who produced the films,
# Distributor:        companies who distributed the films,
# Director:           people who directed the films,
# Writer:             people who wrote the films,
# Actor1:             person 1 who acted in the films,
# Actor2:             person 2 who acted in the films,
# Actor3:             person 3 who acted in the films
# )

# %% [markdown]
# ### SELECT
# SELECT COUNT(Locations) FROM FilmLocations WHERE Writer="James Cameron";
#
# SELECT DISTINCT Title FROM FilmLocations;
#
# SELECT COUNT(DISTINCT ReleaseYear) FROM FilmLocations WHERE ProductionCompany="Warner Bros. Pictures";
#
# SELECT * FROM FilmLocations LIMIT 15 OFFSET 10; #
#     retrieving 15 rows, starting from row 11.
#
# SELECT COUNT(Title) FROM FilmLocations where Locations = "Russian Hill";
#
# SELECT Count(*) FROM FilmLocations WHERE ReleaseYear<1950;
#
# SELECT DISTINCT Title FROM FilmLocations WHERE ReleaseYear = 2015 LIMIT 3 OFFSET 5;

# %% [markdown]
# Instructor (
#     ins_id:     unique identification number of the instructors,
#     lastname:   last name of the instructors,
#     firstname:  first name of the instructors,
#     city:       name of the cities where instructors are located,
#     country:    two-letter country code of the countries where instructors are located
# )

# %% [markdown]
# ### INSERT
# INSERT INTO
# Instructor(ins_id, lastname, firstname, city, country)
# VALUES
# (5, 'Doe', 'John', 'Sydney', 'AU'),
# (6, 'Doe', 'John', 'Dhaka', 'BD');

# %% [markdown]
# ### UPDATE statement
# UPDATE Instructor
# SET lastname = "Doe",
#     firstname = "John",
#     city = "Sydney",
#     country = "AU"
# WHERE ins_id = 5;
#
# SELECT * FROM Instructor;

# %% [markdown]
# ### DELETE
# DELETE
# FROM Instructor
# WHERE ins_id IN (5,4)
# ;
# SELECT *
# FROM Instructor
# ;

# %% [markdown]
# ### SELECT
# SELECT
# COUNT (DISTINCT column_name)
# FROM table_name
# ;
#
# The SELECT statement is called a query, and the output we get from executing the query is called a result set.

# %% [markdown]
# ## Week 2
# Q: What is SQL, Data, DB, RDB, DBMS, RDBMS?
# - What is SQL?
#   - a lang used for RDBS
#   - to query data
# - Data?
#   - facts, img...
#   - needs to be fast, secure
# - Database -> DBMS
#   - a repo of data
#   - fast, secure way to store data
#   - to add/modify/query data
#     - Relational Database -> RDBMS
#       - tabular (columns & rows)
#         - e.g. excel
#         - contains item properties
#     - DBMS : Database Management System
#     - RDBMS
#       - mySQL, Oracle Database, IBM DB2...
#     - CREATE, INSERT, SELECT, UPDATE, DELETE

# %% [markdown]
# ### RDB Concepts
# - Remarks: Explain the advantage, mapping, difference between an entity and attribute, primary keys
# - Most used data model
# - allows for
#   - data independence
# - stored in tables
#   - ERD : Entity Relationship Model:
# - ![image.png](attachment:image.png)

# %% [markdown]
# #### ERD : Entity Relationship Model
# - a tool
# - entity : objects that exist independently
#   - BOOK : entity
#   - TITLE, EDITION... : attributes
#     - attributes maps to columns in a table,
#     - entity maps to table in a RDB
#   - primary keys
#     - e.g. ID - preventing !DISTINCT
#   - Foreign keys
#     - primary keys defined in different tables
#     - creating a link between tables

# %% [markdown]
# ### Cloud DB's
# - Ease of Use and Access
#   - API
#   - Web Interface
#   - Cloud/Remote Apps
# - Scalability & Econ
#   - expand/shrink storage
#   - pay per use
#     - very cheap compared to physical
# - Disaster Recovery
#   - cloud backups
# - IBM db2, PostgreSQL DB's, Oracle DBCS, Azure SQL, Amazon RDS
# - VMs/Managed, Single/Multi-tenant
# - DBaaS - DB as a Service
#   - no hardware/software set-up needed

# %% [markdown]
# ### Types of SQL Statements
# - DDL
#   - Data Definition Language
#   - to define, change, drop data
#   - CREATE, ALTER, TRUNCATE, DROP
# - DML
#   - Data Manipulation Language
#   -  read & modify data
#   -  CRUD operations
#      -  Create, Read, Update, Delete
#   -  INSERT, SELECT, UPDATE, DELETE
